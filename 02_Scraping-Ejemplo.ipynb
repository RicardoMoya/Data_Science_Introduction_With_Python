# %% [markdown]
# # 2 - Scraping
#
#
# * El ***Web Scraping*** (o Scraping) son un conjunto de técnicas que se utilizan para ***obtener de forma automática el contenido que hay en páginas web*** a través de su código HTML.
#
#
# * El uso de estas técnicas tienen como finalidad ***recopilar grandes cantidades de datos de diferentes páginas web*** (se puede enmarcar dentro del Big Data) cuyo uso posterior puede ser muy variado: homogenización de datos, tratamiento de contenido para la extracción de conocimiento, etc.
#
#
# * Existen múltiples librerías en diferentes lenguajes para abordar el ***Scraping***. En Python una de las ***librerías*** más utilizadas es ***“BeautifulSoup”*** para abordar este tipo de tareas y la librería ***“request”*** para las peticiones http.
#
#
# ###### ***NOTA***: En el fichero README.md se indica como instalar las librerías "BeautifulSoup" y "request", así como el resto de librerías necesarias para seguir este curso.
#
# <hr>
#
#
# ## Ejemplo de Scraping a la web de Jarroba.com
#
#
# * A continuación se muestra un ejemplo de como "scrapear" datos de la web de https://jarroba.com/.
#
#
# * Para realizar Scraping tenemos que entender en primer lugar cual es la estructura de la web ("divs", "spans", "tables", etc.).
#
#
# * En este ejemplo vamos a obtener de esta página web información relativa a los Post que publica, obteniendo de la página principal los siguentes datos de cada post:
#
#     1. Nombre del Post
#     2. Autor
#     3. Fecha de publicación
#
#
# * A continuación mostramos la estructura de esta página web:
#
#
# <img src="./imgs/02_01_scraping.png" style="width: 800px;"/>
#
#
# * Podemos observar que:
#     - Cada Post de la página principal se encuentra metido en una etiqueta '*div*' con identificador '*col-md-4 col-xs-12*'
#     - Dentro de cada Post podemos encontar la información relativa al título, autor y fecha dentro de las etiquetas span con los siguientes identificadores:
#         + título: tituloPost
#         + autor: autor
#         + fecha: fecha
#
#
# ### Proceso para scrapear los datos
#
#
# 1. Hacer una petición http a la página web a "scrapear" y ver si esta accesible sin problemas (nos tiene que devolver un status code de 200). En caso de que no sea accesible no procedemos al Scraping.
#
#
# 2. Obtenemos todo el código HTML y lo pasamos a un objeto "*BeautifulSoup*". Esta clase ya se encargará de parsear este HTML a partir de sus etiquetas e identificadores.
#
#
# 3. Creamos una lista que contenga en cada posición el HTML de cada unos de los Post (los "divs" con identificador *col-md-4 col-xs-12*'.
#
#
# 4. Por cada uno de los "divs" de cada entrada, obtenemos el título del post, nombre del autor y fecha a partir de los identificadores antes descritos de las etiquetas "spans".
#
#
# * El código quedaría de la siguente manera:

# %%
from bs4 import BeautifulSoup
import requests

URL = "http://jarroba.com/"

# Realizamos la petición a la web
req = requests.get(URL)

# Comprobamos que la petición nos devuelve un Status Code = 200
status_code = req.status_code
if status_code == 200:

    # Pasamos el contenido HTML de la web a un objeto BeautifulSoup()
    html = BeautifulSoup(req.text, "html.parser")

    # Obtenemos todos los divs donde están las entradas
    entradas = html.find_all('div', {'class': 'col-md-4 col-xs-12'})

    # Recorremos todas las entradas para extraer el título, autor y fecha
    for i, entrada in enumerate(entradas):
        
        # Con el método "getText()" no nos devuelve el HTML
        titulo = entrada.find('span', {'class': 'tituloPost'}).getText()
        
        # Sino llamamos al método "getText()" nos devuelve también el HTML
        autor = entrada.find('span', {'class': 'autor'})
        
        fecha = entrada.find('span', {'class': 'fecha'}).getText()

        # Imprimo el Título, Autor y Fecha de las entradas
        print('{id} - {titulo} - {autor} - {fecha}\n'
              .format(id=i+1, titulo=titulo, autor=autor, fecha=fecha))

else:
    print('Status Code {status_code}'.format(status_code=status_code))
# Out:
# 1 - Pipenv: gestor de entornos virtuales de Python - <span class="autor">Por: Ramón	Invarato</span> - 18-Sep-2020
#
# 2 - Entornos virtuales de Python: común y Anaconda - <span class="autor">Por: Ramón	Invarato</span> - 17-Sep-2020
#
# 3 - Entornos de Python: común y Anaconda (base) - <span class="autor">Por: Ramón	Invarato</span> - 14-Sep-2020
#
# 4 - Curso de Python - <span class="autor">Por: Ramón	Invarato</span> - 22-Jul-2020
#
# 5 - Curso de Python – 0. Entorno de desarrollo para Python - <span class="autor">Por: Ramón	Invarato</span> - 22-Jul-2020
#
# 6 - Curso de Python – 1. Introducción - <span class="autor">Por: Ramón	Invarato</span> - 17-Jul-2020
#
# 7 - Curso de Python – 2. Tipos básicos de datos - <span class="autor">Por: Ramón	Invarato</span> - 17-Jul-2020
#
# 8 - Curso de Python – 3. Colecciones - <span class="autor">Por: Ramón	Invarato</span> - 17-Jul-2020
#
# 9 - Curso de Python – 4. Estructuras de control de flujo - <span class="autor">Por: Ramón	Invarato</span> - 17-Jul-2020

# %% [markdown]
# * En la siguiente imagen podemos ver las relación entre el HTML y el código escrito:
#
#
# <img src="./imgs/02_02_scraping.png" style="width: 1000px;"/>
#
#
# <hr>
#
#
# ### Scraping de todos los Posts de la web
#
#
# * De la misma manera que podemos "scrapear" un HTML, podemos "scrapear" todos los HTMLs que queramos.
#
#
# * Por tanto de la web de https://jarroba.com/ podemos obtener todos los post, ya que estos los divide en páginas
#     - https://jarroba.com/page/2/
#     - https://jarroba.com/page/3/
#     - ...
#     - https://jarroba.com/page/N/
#
#
# * Haciendo una petición a cada una de las páginas (siempre que esta exista) podemos obtener la misma información que en el ejemplo anterior:

# %%
from bs4 import BeautifulSoup
import requests

URL_BASE = "http://jarroba.com/"
MAX_PAGES = 40
counter = 0

for i in range(1, MAX_PAGES):

    # Construyo la URL
    if i > 1:
        url = "%spage/%d/" % (URL_BASE, i)
    else:
        url = URL_BASE

    # Realizamos la petición a la web
    req = requests.get(url)
    # Comprobamos que la petición nos devuelve un Status Code = 200
    statusCode = req.status_code
    if statusCode == 200:

        # Pasamos el contenido HTML de la web a un objeto BeautifulSoup()
        html = BeautifulSoup(req.text, "html.parser")

        # Obtenemos todos los divs donde estan las entradas
        entradas = html.find_all('div', {'class': 'col-md-4 col-xs-12'})

        # Recorremos todas las entradas para extraer el título, autor y fecha
        for entrada in entradas:
            counter += 1
            titulo = entrada.find('span', {'class': 'tituloPost'}).getText()
            autor = entrada.find('span', {'class': 'autor'}).getText()
            fecha = entrada.find('span', {'class': 'fecha'}).getText()

            # Imprimo el Título, Autor y Fecha de las entradas
            print('{id} - {titulo} - {autor} - {fecha}\n'
              .format(id=counter, titulo=titulo, autor=autor, fecha=fecha))

    else:
        # Si ya no existe la página y me da un 400
        break
# Out:
# 1 - Pipenv: gestor de entornos virtuales de Python - Por: Ramón	Invarato - 18-Sep-2020
#
# 2 - Entornos virtuales de Python: común y Anaconda - Por: Ramón	Invarato - 17-Sep-2020
#
# 3 - Entornos de Python: común y Anaconda (base) - Por: Ramón	Invarato - 14-Sep-2020
#
# 4 - Curso de Python - Por: Ramón	Invarato - 22-Jul-2020
#
# 5 - Curso de Python – 0. Entorno de desarrollo para Python - Por: Ramón	Invarato - 22-Jul-2020
#
# 6 - Curso de Python – 1. Introducción - Por: Ramón	Invarato - 17-Jul-2020
#
# 7 - Curso de Python – 2. Tipos básicos de datos - Por: Ramón	Invarato - 17-Jul-2020
#
# 8 - Curso de Python – 3. Colecciones - Por: Ramón	Invarato - 17-Jul-2020
#
# 9 - Curso de Python – 4. Estructuras de control de flujo - Por: Ramón	Invarato - 17-Jul-2020
#
# 10 - Curso de Python – 5. Funciones - Por: Ramón	Invarato - 17-Jul-2020
#
# 11 - Curso de Python – 6. Bibliotecas/Paquetes - Por: Ramón	Invarato - 17-Jul-2020
#
# 12 - Curso de Python – 7. Excepciones - Por: Ramón	Invarato - 17-Jul-2020
#
# 13 - Curso de Python – 8. Ficheros - Por: Ramón	Invarato - 17-Jul-2020
#
# 14 - Generadores en Python – La base del Streaming - Por: Ramón	Invarato - 12-Abr-2020
#
# 15 - ReturnS en Python - Por: Ramón	Invarato - 02-Mar-2020
#
# 16 - Mapa: Algoritmos de Aprendizaje y Conceptos del (Deep) Machine Learning - Por: Ricardo	Moya - 22-Ene-2020
#
# 17 - Nuestro propio servidor Software (Socket con Python) - Por: Ramón	Invarato - 07-Oct-2019
#
# 18 - LAMP paso a paso en tu servidor - Por: Ramón	Invarato - 30-Sep-2019
#
# 19 - Usar Servidores y crear una web - Por: Ramón	Invarato - 03-Sep-2019
#
# 20 - Cliente vs Servidor - Por: Ramón	Invarato - 01-Sep-2019
#
# 21 - Cómo funcionan los Servidores y Servicios de Hosting - Por: Ramón	Invarato - 30-Jul-2019
#
# 22 - Mapeo (Mapping) y Mapeo Mutable (MutableMapping) en Python - Por: Ramón	Invarato - 20-Abr-2019
#
# 23 - Especializa tu propia colección en Python - Por: Ramón	Invarato - 20-Abr-2019
#
# 24 - Vistas de los diccionarios de Python: keys, values e items - Por: Ramón	Invarato - 14-Abr-2019
#
# 25 - repr y str de Python - Por: Ramón	Invarato - 17-Feb-2019
#
# 26 - Resumibles (Hashables) en Python - Por: Ramón	Invarato - 18-Nov-2018
#
# 27 - Mutables e Inmutables - Por: Ramón	Invarato - 05-Ago-2018
#
# 28 - Nuestra propia Colección en Python - Por: Ramón	Invarato - 27-May-2018
#
# 29 - Los trucos del Streaming: generadores, buffer y caché - Por: Ramón	Invarato - 08-Abr-2018
#
# 30 - *args y **kwargs – python, con ejemplos - Por: Ricardo	Moya - 17-Feb-2018
#
# 31 - Binario: Combinación y conversión - Por: Ramón	Invarato - 29-Ago-2017
#
# 32 - Sistema de numeración binario - Por: Ramón	Invarato - 28-Jul-2017
#
# 33 - venv (entornos virtuales) en python - Por: Dionisio	Cortes - 25-Jun-2017
#
# 34 - Como construir el JDK de Java 9 - Por: Dionisio	Cortes - 03-Jun-2017
#
# 35 - Patrón Singleton en Python, con ejemplos - Por: Dionisio	Cortes - 18-May-2017
#
# 36 - Inferencia tipos Java: El operador diamante - Por: Dionisio	Cortes - 06-May-2017
#
# 37 - Gson (JSON) en Java, con ejemplos - Por: Ricardo	Moya - 02-May-2017
#
# 38 - Unidades de medida de la información - Por: Ramón	Invarato - 01-May-2017
#
# 39 - 6 formas de mejorar el rendimiento en python - Por: Dionisio	Cortes - 25-Abr-2017
#
# 40 - Scraping anónimo por la red TOR - Por: Ricardo	Moya - 12-Abr-2017
#
# 41 - Anonymous scraping by TOR network - Por: Ricardo	Moya - 12-Abr-2017
#
# 42 - Bit - Por: Ramón	Invarato - 02-Abr-2017
#
# 43 - Hamming - Por: Ramón	Invarato - 09-Nov-2016
#
# 44 - Código de Hamming: Detección y Corrección de errores - Por: Ramón	Invarato - 05-Oct-2016
#
# 45 - Análisis de resultados de fútbol con Power BI - Por: Ricardo	Moya - 01-Oct-2016
#
# 46 - Selección del número óptimo de Clusters - Por: Ricardo	Moya - 12-Sep-2016
#
# 47 - Tablas Hash (o Tabla de Dispersión) - Por: Ramón	Invarato - 03-Sep-2016
#
# 48 - Dígito de control – Detección de errores - Por: Ramón	Invarato - 21-Jul-2016
#
# 49 - Expectation-maximization en Python y Scikit-learn, con ejemplos - Por: Ricardo	Moya - 20-Jun-2016
#
# 50 - K-means en Python y Scikit-learn, con ejemplos - Por: Ricardo	Moya - 29-May-2016
#
# 51 - ¿Que es el Clustering? - Por: Ricardo	Moya - 25-Mar-2016
#
# 52 - Código Hash - Por: Ramón	Invarato - 02-Mar-2016
#
# 53 - ¿Qué es el Machine Learning? - Por: Ricardo	Moya - 30-Ene-2016
#
# 54 - Lectura y Escritura de ficheros en Python, con ejemplos - Por: Ricardo	Moya - 31-Dic-2015
#
# 55 - Patrón Singleton en Java, con ejemplos - Por: Ricardo	Moya - 21-Dic-2015
#
# 56 - Cliente-Servidor: Petición del Cliente - Por: Ramón	Invarato - 29-Nov-2015
#
# 57 - Curso de Bases de Datos con MySql -Parte V- (Video) «Group By» - Por: Ricardo	Moya - 09-Nov-2015
#
# 58 - Pandas en Python, con ejemplos -Parte I- Introducción - Por: Ricardo	Moya - 30-Oct-2015
#
# 59 - Pandas en Python, con ejemplos -Parte II- Lectura-Escritura, Merge & GroupBy - Por: Ricardo	Moya - 30-Oct-2015
#
# 60 - Pandas en Python, con ejemplos -Parte III- Pivot_table - Por: Ricardo	Moya - 30-Oct-2015
#
# 61 - Como usar multiples cuentas de GitHub (por https) - Por: Ricardo	Moya - 15-Sep-2015
#
# 62 - Ordenar listas en Python, con ejemplos - Por: Ricardo	Moya - 30-Ago-2015
#
# 63 - Annotations (Anotaciones) en Java - Por: Ramón	Invarato - 15-Ago-2015
#
# 64 - Reflection en Java - Por: Ramón	Invarato - 12-Jul-2015
#
# 65 - Scraping en Python (BeautifulSoup), con ejemplos - Por: Ricardo	Moya - 27-May-2015
#
# 66 - Arquitectura Android – ART vs Dalvik - Por: Ramón	Invarato - 17-May-2015
#
# 67 - Scraping en Java (JSoup), con ejemplos - Por: Ricardo	Moya - 12-May-2015
#
# 68 - Diccionario en python, con ejemplos - Por: Ricardo	Moya - 05-May-2015
#
# 69 - Data Set de resultados de partidos de fútbol para su predicción (Machine Learning) - Por: Ricardo	Moya - 26-Abr-2015
#
# 70 - Intalar Ubuntu en una máquina virtual con VirtualBox (Video) - Por: Ricardo	Moya - 15-Abr-2015
#
# 71 - Lectura y Escritura de ficheros en Java, con ejemplos - Por: Ricardo	Moya - 08-Abr-2015
#
# 72 - List en Python, con ejemplos - Por: Ricardo	Moya - 06-Abr-2015
#
# 73 - Python MongoDB Driver (pymongo), con ejemplos (Video) - Por: Ricardo	Moya - 23-Mar-2015
#
# 74 - Java MongoDB Driver, con ejemplos (Video) - Por: Ricardo	Moya - 18-Mar-2015
#
# 75 - Búsqueda de patrones – Expresiones regulares - Por: Ramón	Invarato - 08-Feb-2015
#
# 76 - Maven en Eclipse - Por: Ramón	Invarato - 13-Ene-2015
#
# 77 - Maven - Por: Ramón	Invarato - 12-Ene-2015
#
# 78 - Multitarea e Hilos en Java con ejemplos II (Runnable & Executors) - Por: Ricardo	Moya - 06-Dic-2014
#
# 79 - Libro Android 100% Gratis - Por: Ramón	Invarato - 29-Oct-2014
#
# 80 - Excepciones (Exception) en Java, con ejemplos - Por: Ricardo	Moya - 12-Oct-2014
#
# 81 - Interface en Java 8 -Metodo Default- con ejemplos - Por: Ricardo	Moya - 10-Sep-2014
#
# 82 - Enum (Enumerados) en Java, con ejemplos - Por: Ricardo	Moya - 07-Sep-2014
#
# 83 - Graficas en páginas web con «Google Charts» - Por: Ricardo	Moya - 06-Ago-2014
#
# 84 - MEAN (Mongo-Express-Angular-Node) Ejemplo de Aplicación Web (Parte II) - Por: Ricardo	Moya - 24-Jul-2014
#
# 85 - Configurar un Apache en un servidor Linux (DigitalOcean) con Dominio y Subdominios  (Video) - Por: Ricardo	Moya - 11-Jul-2014
#
# 86 - MEAN (Mongo-Express-Angular-Node) Desarrollo Full Stack JavaScript (Parte I) - Por: Ricardo	Moya - 09-Jul-2014
#
# 87 - Atributos para diseñadores Android (tools:xxxxx) - Por: Ramón	Invarato - 26-May-2014
#
# 88 - Multitarea e Hilos en Java con ejemplos (Thread & Runnable) - Por: Ricardo	Moya - 23-May-2014
#
# 89 - inflate() en Android – Inflar y adjuntar Views - Por: Ramón	Invarato - 10-May-2014
#
# 90 - Configurar formateo de código en Eclipse - Por: Ricardo	Moya - 28-Abr-2014
#
# 91 - Polimorfismo en Java -Interface- (Parte II), con ejemplos - Por: Ricardo	Moya - 24-Abr-2014
#
# 92 - Polimorfismo en Java (Parte I), con ejemplos - Por: Ricardo	Moya - 18-Abr-2014
#
# 93 - Herencia en Java, con ejemplos - Por: Ricardo	Moya - 08-Abr-2014
#
# 94 - Error Android- El SDK de Android no permite actualizar - Por: Ramón	Invarato - 06-Mar-2014
#
# 95 - Map  en Java, con ejemplos - Por: Ricardo	Moya - 01-Mar-2014
#
# 96 - Como crear entornos de desarrollo con Vagrant y Puppet (Video) - Por: Ricardo	Moya - 19-Feb-2014
#
# 97 - ¿Qué es la innovación? Parte IV (Incertidumbre en la Innovación) - Por: Ricardo	Moya - 03-Feb-2014
#
# 98 - Curso de MongoDB -Parte I- (Video) – «Introducción» - Por: Ricardo	Moya - 17-Ene-2014
#
# 99 - Acelerar el emulador de Android - Por: Ramón	Invarato - 11-Ene-2014
# 100 - ¿Que es la innovación? Parte III (Tipos de innovación) - Por: Ricardo	Moya - 09-Ene-2014
#
# 101 - ¿Qué es la innovación? Parte II (Modelo Social de Adopción de Tecnologías) - Por: Ricardo	Moya - 05-Ene-2014
#
# 102 - ¿Qué es la innovación? Parte I (Conceptos y Ejemplos) - Por: Ricardo	Moya - 02-Ene-2014
#
# 103 - Error Android – Eclipse no muestra los botones de Android después de instalar el ADT y el SDK - Por: Ramón	Invarato - 30-Dic-2013
#
# 104 - AJAX con JSP y Servelts - Por: Ricardo	Moya - 21-Dic-2013
#
# 105 - Ordenar un ArrayList en Java - Por: Ricardo	Moya - 26-Nov-2013
#
# 106 - Auto Layout iOS 7 (Video) - Por: Ricardo	Moya - 20-Nov-2013
#
# 107 - ListView de Android en pocas líneas - Por: Ramón	Invarato - 02-Nov-2013
#
# 108 - Context de Android - Por: Ramón	Invarato - 27-Oct-2013
#
# 109 - Modo Debug en Eclipse para Java – (Video) - Por: Ricardo	Moya - 20-Oct-2013
#
# 110 - AsyncTask en Android - Por: Ramón	Invarato - 30-Sep-2013
#
# 111 - Multitarea en Android - Por: Ramón	Invarato - 26-Sep-2013
#
# 112 - Sistemas de Recomendación basados en Filtrado Colaborativo (K-Vecinos) - Por: Ricardo	Moya - 24-Sep-2013
#
# 113 - Instalar mongoDB en Mac OS X - Por: Ricardo	Moya - 17-Sep-2013
#
# 114 - Introducción a las Redes Neuronales – El perceptrón- (Video) - Por: Ricardo	Moya - 16-Sep-2013
#
# 115 - Tab Bar Controller en Objective-C -Ejemplo- (Video) - Por: Ricardo	Moya - 01-Sep-2013
#
# 116 - Collection View (Grids) en Objective-C -Ejemplo- (Video) - Por: Ricardo	Moya - 25-Ago-2013
#
# 117 - Programar Fragments (fragmentos) en Android - Por: Ramón	Invarato - 19-Ago-2013
#
# 118 - Fragments (fragmentos) en Android - Por: Ramón	Invarato - 19-Ago-2013
#
# 119 - Reproducción de Sonidos en Android (Video) - Por: Ricardo	Moya - 27-Jul-2013
#
# 120 - ¿Que son los Sistemas de Recomendación? - Por: Ricardo	Moya - 21-Jul-2013
#
# 121 - Graficas en páginas web con Highcharts - Por: Ricardo	Moya - 14-Jul-2013
#
# 122 - UITableView en Objective-C -Ejemplo- (Video) - Por: Ricardo	Moya - 01-Jun-2013
#
# 123 - Error Android – java.lang.NoClassDefFoundError sin motivo aparente - Por: Ramón	Invarato - 30-May-2013
#
# 124 - Algoritmos Genéticos – Ejemplo - Por: Ricardo	Moya - 25-May-2013
#
# 125 - Expansión al ListView o listado en Android - Por: Ramón	Invarato - 25-May-2013
#
# 126 - Introducción a Android Studio (Video) - Por: Ricardo	Moya - 19-May-2013
#
# 127 - ¿Que es la Computación Evolutiva? - Por: Ricardo	Moya - 18-May-2013
#
# 128 - Multitaréa e Hilos, fácil y muchas ventajas - Por: Ramón	Invarato - 23-Abr-2013
#
# 129 - Ordenar Arrays en Java (con sus indices) - Por: Ricardo	Moya - 20-Abr-2013
#
# 130 - Tablas con JavaFX y FXML (Video) - Por: Ricardo	Moya - 14-Abr-2013
#
# 131 - ArrayList en Java, con ejemplos - Por: Ricardo	Moya - 28-Mar-2013
#
# 132 - Intent – Pasar datos entre Activities – App Android (Video) - Por: Ricardo	Moya - 03-Mar-2013
#
# 133 - ListView o listado en Android - Por: Ramón	Invarato - 13-Feb-2013
#
# 134 - UIWebView -iPhone- (Vídeo) - Por: Ricardo	Moya - 28-Ene-2013
#
# 135 - Pintar Funciones en JavaFX (LineChart) - Por: Ricardo	Moya - 26-Ene-2013
#
# 136 - Multiples Pickerviews en una vista -iPhone- (Video) - Por: Ricardo	Moya - 18-Ene-2013
#
# 137 - Pasar de un ViewController a otro automaticamente (iPhone) - Por: Ricardo	Moya - 28-Dic-2012
#
# 138 - Introducción a JUnit – (Video) - Por: Ricardo	Moya - 26-Dic-2012
#
# 139 - Error Android – La conexión al adb se ha caído y ha ocurrido un problema grave - Por: Ramón	Invarato - 20-Nov-2012
#
# 140 - Error Android – La instalación del SDK no detecta el JDK de Java - Por: Ramón	Invarato - 04-Nov-2012
#
# 141 - Activity – entender y usar una Actividad - Por: Ramón	Invarato - 04-Nov-2012
#
# 142 - Introducción a Interfaces Gráficas con JavaFX y SceneBuilder (Video) - Por: Ricardo	Moya - 02-Nov-2012
#
# 143 - Curso de Python -Parte I- (Video) «Configurar Eclipse» - Por: Ricardo	Moya - 01-Oct-2012
#
# 144 - Cambiar la clave por defecto de acceso al Menú de Configuración del Router ADSL (Seguridad Mínima) - Por: Ramón	Invarato - 28-Sep-2012
#
# 145 - Curso de Bases de Datos con MySql -Parte IV- (Video) «INNER JOIN» - Por: Ricardo	Moya - 28-Sep-2012
#
# 146 - Primer contacto con el Router ADSL – Acceder a su Menú de Configuración - Por: Ramón	Invarato - 23-Sep-2012
#
# 147 - NSTimer en Objective-C -Ejemplo- (Video) - Por: Ricardo	Moya - 30-Ago-2012
#
# 148 - Pasar Datos entre ViewControllers usando StoryBoards y Segues (Video) - Por: Ricardo	Moya - 28-Ago-2012
#
# 149 - ¿Cómo proteger nuestra red inalámbrica Wi-Fi? - Por: Ramón	Invarato - 25-Ago-2012
#
# 150 - Curso de Bases de Datos con MySql -Parte III- (Video) Definition/Manipulation - Por: Ricardo	Moya - 21-Ago-2012
#
# 151 - Curso de Bases de Datos con MySql -Parte II- (Video) -Entidad/Relación- - Por: Ricardo	Moya - 16-Ago-2012
#
# 152 - Curso de Bases de Datos con MySql -Parte I- (Video) - Por: Ricardo	Moya - 15-Ago-2012
#
# 153 - Conocer para prevenir los peligros de Internet - Por: Ramón	Invarato - 28-Jul-2012
#
# 154 - Punto de Acceso Inalámbrico – ¿Cómo funciona la Wi-Fi? - Por: Ramón	Invarato - 21-Jul-2012
#
# 155 - Router ADSL – ¿Cómo funciona esa caja que solo sirve para dar Internet? - Por: Ramón	Invarato - 21-Jul-2012
#
# 156 - Proveedor de Servicios de Internet – ¿Cómo llega Internet hasta nuestra casa? - Por: Ramón	Invarato - 21-Jul-2012
#
# 157 - Banner rotatorio con JavaScript - Por: Ricardo	Moya - 10-Jul-2012
#
# 158 - Como programar en C con el Xcode en Mac (VIDEO) - Por: Ricardo	Moya - 26-Jun-2012
#
# 159 - Como solucionar errores en Android - Por: Ramón	Invarato - 23-Jun-2012
#
# 160 - [DEPRECATED] Obtener FingerPrint y ApiKey para Android Maps (VIDEO) - Por: Ricardo	Moya - 15-Jun-2012
#
# 161 - Paradigmas de Programación - Por: Ricardo	Moya - 09-Jun-2012
#
# 162 - Como programar Webs y Servlets en Eclipse - Por: Ramón	Invarato - 26-May-2012
#
# 163 - Instalar un contenedor de Servlets local: Tomcat - Por: Ramón	Invarato - 25-May-2012
#
# 164 - Preparar las herramientas necesarias para programar en Android - Por: Ramón	Invarato - 13-May-2012
#
# 165 - Como configurar el Eclipse para programar en PHP (VIDEO) - Por: Ricardo	Moya - 22-Abr-2012
#
# 166 - Mucho Java en un sencillo tutorial (para Dummies) - Por: Ramón	Invarato - 11-Abr-2012
#
# 167 - Instalación del Xilinx ISE - Por: Ricardo	Moya - 03-Abr-2012
#
# 168 - Modelo “4+1” vistas de Kruchten (para Dummies) - Por: Ricardo	Moya - 31-Mar-2012
#
# 169 - Espacio de trabajo para guardar los proyectos que creemos en Eclipse - Por: Ramón	Invarato - 29-Mar-2012
#
# 170 - Instalar el SDK de Android y vincularlo con Eclipse - Por: Ramón	Invarato - 17-Mar-2012
#
# 171 - Instalar Snow Leopard (OS) en VMware bajo Windows - Por: Ramón	Invarato - 01-Mar-2012
#
# 172 - Instalar bien Eclipse (es un IDE de muchos) - Por: Ramón	Invarato - 26-Feb-2012
#
# 173 - Instalación del Python Robotics (Pyro) (VIDEO) - Por: Ricardo	Moya - 25-Feb-2012
#
# 174 - Instalación del WordPress en un servidor local (XAMPP) - Por: Ricardo	Moya - 19-Feb-2012
#
# 175 - Lo que el modelado puede hacer por tí - Por: Ramón	Invarato - 14-Feb-2012
#
# 176 - Aprender a programar conociendo lo que es un Entorno de Desarrollo Integrado (IDE) - Por: Ramón	Invarato - 14-Feb-2012
#
# 177 - Instalación del XAMPP para Windows - Por: Ricardo	Moya - 13-Feb-2012
#
# 178 - Error Android – El emulador se desconecta y no lanza la aplicación - Por: Ramón	Invarato - 12-Dic-2011
#
# 179 - Error Android – Error en los métodos con anotaciones @Override, de tipo Listener o sobrescritos - Por: Ramón	Invarato - 12-Dic-2011
#
# 180 - Error Android – Problemas con algún proyecto importado o de ejemplo de Android - Por: Ramón	Invarato - 12-Dic-2011
#
# 181 - Error Android – Problemas al instalar el ADT o el SDK - Por: Ramón	Invarato - 12-Dic-2011
#
# 182 - Error Android – Error en las librerías importadas - Por: Ramón	Invarato - 12-Dic-2011
#
# 183 - Error Android – Certificado diferente al intentar reinstalar la aplicación en el emulador o el teléfono - Por: Ramón	Invarato - 12-Dic-2011
#
# 184 - Error Android – Certificado de depuración caducado - Por: Ramón	Invarato - 12-Dic-2011
#
# 185 - Error Android – Referencias perdidas - Por: Ramón	Invarato - 12-Dic-2011
#
# 186 - Error Android – Se requiere un compilador de nivel superior - Por: Ramón	Invarato - 12-Dic-2011
#
# 187 - Error Android – Se requiere un ADT superior - Por: Ramón	Invarato - 12-Dic-2011
#
# 188 - Error Android – No se encuentra el SDK de android - Por: Ramón	Invarato - 12-Dic-2011
#
# 189 - Error Android – Salto de algún archivo indexado - Por: Ramón	Invarato - 12-Dic-2011
# 190 - Error Android – Eclipse lanza un error que no existe por ningún lado - Por: Ramón	Invarato - 12-Dic-2011
#
# 191 - Error Android – El log no muestra nada - Por: Ramón	Invarato - 12-Dic-2011
#
# 192 - Error Android – Aplicación no especifica el nivel de la API - Por: Ramón	Invarato - 12-Dic-2011

# %% [markdown]
# <hr>
#
#
# # Bonus Track - Scraping Anónimo
#
#
# * Uno de los problemas que tiene el Scraping (si se hace de forma masiva) es que las webs suelen tener un sistema de protección para que desde una misma IP no se hagan más de 'N' peticiones por unidad de tiempo; por ejemplo, más de 200 peticiones por minúto desde una misma IP.
#
#
# * Para resolver estos problemas lo que se suele hacer es contratar un servicio de "proxis" para que te ofrezca diferentes IPs para hacer peticiones. Este tipo de servicio suele ser muy caro si se quiere hacer bien.
#
#
# * Otra opción es hacer Scraping por medio de la red TOR. Hacer Scraping de esta manera ya es algo más complejo debido a que hay que gestionar conexiones, configurar un servicio proxy, etc.
#
#
# * Si se quiere profuncizar en este tema se mustran a continuación dos enlaces de interes en los que se explican "*Cómo configurar un servidor proxy para realizar scraping de forma anónima por medio de la red TOR*"
#
#     - https://jarroba.com/scraping-anonimo-la-red-tor/
#     - https://github.com/RicardoMoya/Scraping_Proxy_Tor
#
#
# <hr>
#
# *Este Notebook ha sido desarrollado por **Ricardo Moya García** y registrado en Safe Creative como ***Atribución-NoComercial-CompartirIgual***.*
#
# <img src="./imgs/CC_BY-NC-SA.png" alt="CC BY-NC">
